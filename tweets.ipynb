# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import time
import json

# %%
access_token = "2969365504-mTB2nnp9hjmyPkEo0hDXwFT7PisylCQt85XlP2z"
access_token_secret= "b3T0xWoNP93EEePrFHYtnUqzIxMVxDXZ3tzIeE7uZY7am"
consumer_key = "qXYgNzuWuOiUuP438sRnC8FcG"
consumer_secret = "oNFuDtY26Jo5pkp3qDS897DOVO6dAtGI05UX1pIVIeU3BtJhAF"

# %%
class MyStreamListener(StreamListener):
    def on_data(self, data):
        try:
            print(data)
            savefile = open('tweets.txt','a')
            savefile.write(data)
            savefile.write('\n')
            savefile.close()
            return True
        except BaseException,e:
            print('Failed on Date'.str(e))
            time.sleep(5)
        def on_eff(self,status):
            print(status)

# %%
if __name__=='main':
    auth = OAuthHandler(consumer_key,consumer_secret)
    auth.set_access_token(access_token,access_token_secret)
    l = MyStreamListener()
    stream = Stream(auth,l)
    stream.filter(track=['Cristiano Ronaldo','Didier Drogba','Neymar'])

# %%
tweets_data_path = "tweets.txt"
tweets_data = []
tweets_file = open(tweets_data_path, 'r')
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/xiadylan

# %%
tweets_data
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
tweets_data[0].keys()
# Out:
# [u'quote_count',
#  u'contributors',
#  u'truncated',
#  u'text',
#  u'is_quote_status',
#  u'in_reply_to_status_id',
#  u'reply_count',
#  u'id',
#  u'favorite_count',
#  u'source',
#  u'retweeted',
#  u'coordinates',
#  u'timestamp_ms',
#  u'entities',
#  u'in_reply_to_screen_name',
#  u'in_reply_to_user_id',
#  u'retweet_count',
#  u'id_str',
#  u'favorited',
#  u'user',
#  u'geo',
#  u'in_reply_to_user_id_str',
#  u'possibly_sensitive',
#  u'lang',
#  u'created_at',
#  u'filter_level',
#  u'in_reply_to_status_id_str',
#  u'place']

# %%
tweets_data[0]['text']
text_list = [tweet['text'] for tweet in tweets_data]
lang_list = [tweet['text'] for tweet in tweets_data]
cust_dict = {'text':text_list,'lang':lang_list}

data=pd.DataFrame.from_dict(cust_dict)
data.to_csv('tweets_pol.csv',encoding='utf-8')

# %%
df = pd.DataFrame(tweets_data,columns=['text','lang'])

# %%
df
# Out:
#                                                   text lang
# 0    Sau 2 lượt trận tại Champions League 2017, tra...   vi
# 1    RT @SoyFan10: ¡ENORME!\n\nCristiano Ronaldo de...   es
# 2    RT @_StrictlyFutbol: .@Cristiano Ronaldo's bra...   en
# 3    RT @TheSunFootball: Cristiano Ronaldo shows of...   en
# 4                 RT @LucianaGimenez: mataram o neymar   pt
# 5    Vcs querem beleza? Toma beleza 😍 https://t.co...   pt
# 6    RT @Torren__: Que te canten "Cristiano Ronaldo...   es
# 7    RT @Sporf: WOW: @Cristiano Ronaldo's brand-new...   en
# 8    Neymar menuduh media mengarang-ngarang cerita ...   in
# 9    RT @InvictosSomos: El nuevo juguetito de Crist...   es
# 10   Y que tiene que ver esto? La escena anterior e...   es
# 11   Seguro esta barato comprarse un campo https://...   es
# 12   RT @NiveaStella: Meta de vida https://t.co/9rH...   es
# 13   RT @WORLDSTAR: Cristiano Ronaldo’s Bugatti Chi...   en
# 14   RT @BuzzDeFoot: Cette petite fille qui reprodu...   fr
# ...

# %%
Cristiano = 0
Didier = 0
Neymar = 0

# %%
import re

# %%
def word_in_text(word,tweet):
    word = word.lower()
    text = tweet.lower()
    match = re.search(word,tweet)
    
    if match:
        return True
    return False

# %%
for index, row in df.iterrows():
    Cristiano = Cristiano + word_in_text('cristiano ronaldo',row['text'])
    Didier = Didier + word_in_text('didier',row['text'])
    Neymar = Neymar + word_in_text('neymar',row['text'])

# %%
Cristiano
# Out:
# 2

# %%
df['text3'] = df['text'].str.split('@')

# %%
df['text1'] = df['text'].str.get(4)

# %%
#df['text2'] = df['text'].str.get(3)

# %%
df
# Out:
#                                                   text lang  \
# 0    Sau 2 lượt trận tại Champions League 2017, tra...   vi
# 1    RT @SoyFan10: ¡ENORME!\n\nCristiano Ronaldo de...   es
# 2    RT @_StrictlyFutbol: .@Cristiano Ronaldo's bra...   en
# 3    RT @TheSunFootball: Cristiano Ronaldo shows of...   en
# 4                 RT @LucianaGimenez: mataram o neymar   pt
# 5    Vcs querem beleza? Toma beleza 😍 https://t.co...   pt
# 6    RT @Torren__: Que te canten "Cristiano Ronaldo...   es
# 7    RT @Sporf: WOW: @Cristiano Ronaldo's brand-new...   en
# 8    Neymar menuduh media mengarang-ngarang cerita ...   in
# 9    RT @InvictosSomos: El nuevo juguetito de Crist...   es
# 10   Y que tiene que ver esto? La escena anterior e...   es
# 11   Seguro esta barato comprarse un campo https://...   es
# 12   RT @NiveaStella: Meta de vida https://t.co/9rH...   es
# 13   RT @WORLDSTAR: Cristiano Ronaldo’s Bugatti Chi...   en
# 14   RT @BuzzDeFoot: Cette petite fille qui reprodu...   fr
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tweets = pd.read_csv('tweets_pol.csv')

# %%
#tweets['text'] = map(lambda tweet: tweet['text'],tweets_data)

# %%
tweets
# Out:
#      Unnamed: 0                                               lang  \
# 0             0  Sau 2 lượt trận tại Champions League 2017, tra...
# 1             1  RT @SoyFan10: ¡ENORME!\n\nCristiano Ronaldo de...
# 2             2  RT @_StrictlyFutbol: .@Cristiano Ronaldo's bra...
# 3             3  RT @TheSunFootball: Cristiano Ronaldo shows of...
# 4             4               RT @LucianaGimenez: mataram o neymar
# 5             5  Vcs querem beleza? Toma beleza 😍 https://t.co...
# 6             6  RT @Torren__: Que te canten "Cristiano Ronaldo...
# 7             7  RT @Sporf: WOW: @Cristiano Ronaldo's brand-new...
# 8             8  Neymar menuduh media mengarang-ngarang cerita ...
# 9             9  RT @InvictosSomos: El nuevo juguetito de Crist...
# 10           10  Y que tiene que ver esto? La escena anterior e...
# 11           11  Seguro esta barato comprarse un campo https://...
# 12           12  RT @NiveaStella: Meta de vida https://t.co/9rH...
# ...

# %%
tweets
